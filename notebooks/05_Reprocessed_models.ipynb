# %% [markdown]
# #### Reprocessing raw output files from the OECD Toolbox and Biotransformer in light of reviewer comments

# %%
import numpy as np
import os as os
import pandas as pd
import seaborn as sns
import sygma

from rdkit import DataStructs
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import AllChem
from rdkit.Chem import PandasTools
from rdkit.Chem import Descriptors
from rdkit.Chem import rdMolDescriptors
from rdkit.Chem.Draw import MolsToGridImage

from IPython.core.display import HTML

# %%
TOP = os.getcwd().replace('notebooks', '')

# %%
raw_dat_dir = TOP + 'data/raw/'
processed_dat_dir = TOP + 'data/processed/'
interim_dat_dir = TOP + 'data/interim/'
figures_dir = TOP + 'reports/figures/'
external_dir = TOP + 'data/external/'

# %%
import sys

sys.path.append(TOP + 'src/data/')

from model_comp import *

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
DSSToxList = pd.read_csv(raw_dat_dir+"CompToxList.csv", header = 0)
DSSToxList = DSSToxList.rename(columns={'INCHIKEY':'Parent_INCHIKEY'})
DSSToxList['QSAR_READY_INCHIKEY'] = SMILES_to_InchiKey(DSSToxList['QSAR_READY_SMILES'],stereoisomer = False)
#DSSToxList.to_csv(raw_dat_dir + 'Processed_CompToxList_v1.csv')
Norm_DTXSID_dict = dict(zip(DSSToxList['Parent_INCHIKEY'],DSSToxList['DTXSID']))
QSAR_DTXSID_dict = dict(zip(DSSToxList['QSAR_READY_INCHIKEY'],DSSToxList['DTXSID']))

# %% [markdown]
# #### ToolBox in vitro predictions

# %%
pd.read_excel(raw_dat_dir+'TB_out_ivt.xlsx', sheet_name = None).keys()
# Out:
# dict_keys(['TB_out_ivt'])

# %%
TB_ivt = pd.read_excel(raw_dat_dir+'TB_out_ivt.xlsx', sheet_name = 'TB_out_ivt')

# %%
import re
p = re.compile(r'DTXSID\d{1,}')

# %%
dtxsid = [m.group(0) for l in TB_ivt['Chemical name(s)'] for m in [p.search(l)] if m]

# %%
len(dtxsid)
# Out:
# 231

# %%
TB_ivt['DTXSID'] = dtxsid

# %%
TB_ivt[['DTXSID', ]]
# Out:
# Index(['#', 'CAS Number', 'Chemical name(s)', 'SMILES', 'Simulator name',
#        'Metabolite', 'DTXSID'],
#       dtype='object')

# %%
TB_ivt = TB_ivt[['DTXSID', 'SMILES', 'Metabolite']]

# %%
def TBivt_cleanup(df, DTXSIDdict):
    """Cleans and returns  a dataframe for the exported OCED Toolbox metabolite data.""" 
    """"Input file requires that SMILES by exported as part of the .csv file. The DTXSDIdict argument should be a dictionary with the QSAR Ready InChI keys as the key and the DSTXID as teh value."""
    """If issues occur reading the file, try coding = 'UTF-16' and delimiter = '\t' """                                                                          #Removes empty bottom row
    df = df[df.Metabolite.notnull()]                                                        #Establishes boolean list indicating indecies with metabolite
    df['Metabolite_INCHIKEY'] = SMILES_to_InchiKey(df['Metabolite'])                        #Converts metabolite SMILES to InChI keys
    df['Parent_INCHIKEY'] = SMILES_to_InchiKey(df['SMILES'],stereoisomer=False)             #Converts parent SMILES to QSAR Ready InChI keys (removes stereoisomer features during conversion)
    df['DTXSID_'] = [DTXSIDdict.get(e) for e in df['Parent_INCHIKEY']]                       #Uses dictionary of parent molecules to extract 
    df['TB_ivt'] = 1                                                                       #Generate column indicating the model source of the metabolite
    df = df.drop_duplicates()    
    df['Clean_SMILES'] = clean_SMILES(df['Metabolite'])                                    
    return df[['DTXSID', 'DTXSID_','Metabolite_INCHIKEY','Clean_SMILES','TB_ivt']];

# %%
ToolBox_ivt = TBivt_cleanup(TB_ivt, QSAR_DTXSID_dict)
# Out:
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Charges were rearranged
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:24:30] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# <ipython-input-26-e357d0c82ac0>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Metabolite_INCHIKEY'] = SMILES_to_InchiKey(df['Metabolite'])                        #Converts metabolite SMILES to InChI keys
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Charges were rearranged
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# <ipython-input-26-e357d0c82ac0>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Parent_INCHIKEY'] = SMILES_to_InchiKey(df['SMILES'],stereoisomer=False)             #Converts parent SMILES to QSAR Ready InChI keys (removes stereoisomer features during conversion)
# <ipython-input-26-e357d0c82ac0>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DTXSID_'] = [DTXSIDdict.get(e) for e in df['Parent_INCHIKEY']]                       #Uses dictionary of parent molecules to extract
# <ipython-input-26-e357d0c82ac0>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TB_ivt'] = 1                                                                       #Generate column indicating the model source of the metabolite

# %%
ToolBox_ivt.drop('DTXSID', axis = 1, inplace = True)

# %%
ToolBox_ivt
# Out:
#            DTXSID_          Metabolite_INCHIKEY  \
# 1    DTXSID0044151  RPHKINMPYFJSCF-UHFFFAOYSA-N
# 2    DTXSID0044151  DFWXYHZQNLIBLY-UHFFFAOYSA-N
# 3    DTXSID0044151  VUCKZBYGRGKCCQ-UHFFFAOYSA-N
# 4    DTXSID0044151  WSIDAANKKVDFNY-UHFFFAOYSA-N
# 6    DTXSID6025725  VYBFQVODGUQVGO-UHFFFAOYSA-N
# ..             ...                          ...
# 224  DTXSID5021889  NZBRXFKHZBOFBW-UHFFFAOYSA-N
# 225  DTXSID5021889  SVTBMSDMJJWYQN-UHFFFAOYSA-N
# 226  DTXSID5021889  PNJNLCNHYSWUPT-UHFFFAOYSA-N
# 228  DTXSID7020762  CSCPPACGZOOCGX-UHFFFAOYSA-N
# 230  DTXSID8021482  KFZMGEQAYNKOFK-UHFFFAOYSA-N
#
#                                Clean_SMILES  TB_ivt
# 1                           Nc1cc(N)cc(N)c1       1
# 2                Nc1cc(N)cc([N+](=O)[O-])c1       1
# 3               Nc1cc(NO)cc([N+](=O)[O-])c1       1
# 4    O=[N+]([O-])c1cc(NO)cc([N+](=O)[O-])c1       1
# 6                Nc1cc(O)cc([N+](=O)[O-])c1       1
# ..                                      ...     ...
# 224                           CC(=O)CC(C)CO       1
# 225                          CC(O)CC(C)(C)O       1
# 226                            CC(O)CC(C)CO       1
# 228                                 CC(C)=O       1
# 230                                  CC(C)O       1
#
# [194 rows x 4 columns]

# %%
ToolBox_ivt.to_csv(processed_dat_dir+'Toolbox_ivt.csv')

# %% [markdown]
# #### Toolbox in vivo predictions

# %%
TB_iv = pd.read_excel(raw_dat_dir+'TB_out_iv.xlsx', sheet_name = 'TB_out_iv')

# %%
TB_iv
# Out:
#       #                                   Chemical name(s)  \
# 0     1  3,5-Dinitro-phenylamine;3,5-Dinitroaniline;3,5...
# 1     1  3,5-Dinitro-phenylamine;3,5-Dinitroaniline;3,5...
# 2     2  3-Nitro-benzeneamine;3-Nitro-phenylamine;3-Nit...
# 3     2  3-Nitro-benzeneamine;3-Nitro-phenylamine;3-Nit...
# 4     2  3-Nitro-benzeneamine;3-Nitro-phenylamine;3-Nit...
# ..   ..                                                ...
# 268  37  2-Propanone;Acetone;acetone 67-64-1 58.1 232 1...
# 269  37  2-Propanone;Acetone;acetone 67-64-1 58.1 232 1...
# 270  37  2-Propanone;Acetone;acetone 67-64-1 58.1 232 1...
# 271  37  2-Propanone;Acetone;acetone 67-64-1 58.1 232 1...
# 272  37  2-Propanone;Acetone;acetone 67-64-1 58.1 232 1...
#
#                                     SMILES                    Simulator name  \
# 0    Nc1cc(cc(c1)[N+]([O-])=O)[N+]([O-])=O                               NaN
# 1    Nc1cc(cc(c1)[N+]([O-])=O)[N+]([O-])=O  in vivo Rat metabolism simulator
# 2                  Nc1cccc(c1)[N+]([O-])=O                               NaN
# 3                  Nc1cccc(c1)[N+]([O-])=O  in vivo Rat metabolism simulator
# 4                  Nc1cccc(c1)[N+]([O-])=O  in vivo Rat metabolism simulator
# ..                                     ...                               ...
# 268                                CC(C)=O  in vivo Rat metabolism simulator
# 269                                CC(C)=O  in vivo Rat metabolism simulator
# 270                                CC(C)=O  in vivo Rat metabolism simulator
# 271                                CC(C)=O  in vivo Rat metabolism simulator
# 272                                CC(C)=O  in vivo Rat metabolism simulator
#
#                      Metabolite
# 0                           NaN
# 1    Nc1cc(N)cc(c1)[N+]([O-])=O
# 2                           NaN
# 3             NC1=CC(=N)C=CC1=O
# 4               Nc1ccc(O)c(N)c1
# ..                          ...
# 268                 CC(O)C(O)=O
# 269                    CC(O)C=O
# 270                     CC(O)CO
# 271                        CC=O
# 272                         CCO
#
# [273 rows x 5 columns]

# %%
dtxsids = [m.group(0) for l in TB_iv['Chemical name(s)'] for m in [p.search(l)] if m]

# %%
TB_iv['DTXSID'] = dtxsids

# %%
TB_iv = TB_iv[['DTXSID', 'Metabolite','SMILES']]

# %%
def TBiv_cleanup(df, DTXSIDdict):
    """Cleans and returns  a dataframe for the exported OCED Toolbox metabolite data.""" 
    """"Input file requires that SMILES by exported as part of the .csv file. The DTXSDIdict argument should be a dictionary with the QSAR Ready InChI keys as the key and the DSTXID as teh value."""
    """If issues occur reading the file, try coding = 'UTF-16' and delimiter = '\t' """                                                                          #Removes empty bottom row
    df = df[df.Metabolite.notnull()]                                                        #Establishes boolean list indicating indecies with metabolite
    df['Metabolite_INCHIKEY'] = SMILES_to_InchiKey(df['Metabolite'])                        #Converts metabolite SMILES to InChI keys
    df['Parent_INCHIKEY'] = SMILES_to_InchiKey(df['SMILES'],stereoisomer=False)             #Converts parent SMILES to QSAR Ready InChI keys (removes stereoisomer features during conversion)
    df['DTXSID_'] = [DTXSIDdict.get(e) for e in df['Parent_INCHIKEY']]                       #Uses dictionary of parent molecules to extract 
    df['TB_iv'] = 1                                                                       #Generate column indicating the model source of the metabolite
    df = df.drop_duplicates()    
    df['Clean_SMILES'] = clean_SMILES(df['Metabolite'])                                    
    return df[['DTXSID', 'DTXSID_','Metabolite_INCHIKEY','Clean_SMILES','TB_iv']];

# %%
ToolBox_iv = TBiv_cleanup(TB_iv, QSAR_DTXSID_dict)
# Out:
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:25:21] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# <ipython-input-53-554a719e12a8>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Metabolite_INCHIKEY'] = SMILES_to_InchiKey(df['Metabolite'])                        #Converts metabolite SMILES to InChI keys
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged; Omitted undefined stereo
# RDKit WARNING: [13:58:47] WARNING: Charges were rearranged; Omitted undefined stereo
# <ipython-input-53-554a719e12a8>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Parent_INCHIKEY'] = SMILES_to_InchiKey(df['SMILES'],stereoisomer=False)             #Converts parent SMILES to QSAR Ready InChI keys (removes stereoisomer features during conversion)
# <ipython-input-53-554a719e12a8>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DTXSID_'] = [DTXSIDdict.get(e) for e in df['Parent_INCHIKEY']]                       #Uses dictionary of parent molecules to extract
# <ipython-input-53-554a719e12a8>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TB_iv'] = 1                                                                       #Generate column indicating the model source of the metabolite

# %%
assert ToolBox_iv['DTXSID'].sum() == ToolBox_iv['DTXSID_'].sum()

# %%
ToolBox_iv.drop(['DTXSID_'], axis = 1, inplace = True)

# %%
ToolBox_iv
# Out:
#             DTXSID          Metabolite_INCHIKEY                Clean_SMILES  \
# 1    DTXSID0044151  DFWXYHZQNLIBLY-UHFFFAOYSA-N  Nc1cc(N)cc([N+](=O)[O-])c1
# 3    DTXSID6025725  BFMDYVWVKQUBGP-UHFFFAOYSA-N         N=C1C=CC(=O)C(N)=C1
# 4    DTXSID6025725  XIWMTQIUUWJNRP-UHFFFAOYSA-N             Nc1ccc(O)c(N)c1
# 5    DTXSID6025725  WZCQRUWWHSTZEM-UHFFFAOYSA-N                Nc1cccc(N)c1
# 7    DTXSID8031077  WSFSSNUMVMOOMR-UHFFFAOYSA-N                         C=O
# ..             ...                          ...                         ...
# 268  DTXSID8021482  JVTAAEKCZFNVCJ-UHFFFAOYSA-N                 CC(O)C(=O)O
# 269  DTXSID8021482  BSABBBMNWQWLLU-UHFFFAOYSA-N                    CC(O)C=O
# 270  DTXSID8021482  DNIAPMSPPWPWGF-UHFFFAOYSA-N                     CC(O)CO
# 271  DTXSID8021482  IKHGUXGNUITLKF-UHFFFAOYSA-N                        CC=O
# 272  DTXSID8021482  LFQSCWFLJHTTHZ-UHFFFAOYSA-N                         CCO
#
#      TB_iv
# 1        1
# 3        1
# 4        1
# 5        1
# 7        1
# ..     ...
# 268      1
# 269      1
# 270      1
# 271      1
# 272      1
#
# [236 rows x 4 columns]

# %%
ToolBox_iv.to_csv(processed_dat_dir+'Toolbox_iv.csv')

# %% [markdown]
# #### BioTransformer v3

# %%
BioTransformer_rev = pd.read_csv(raw_dat_dir+'metsim_0312021.csv')

# %%
bioTransformerDF = BioTransformer_cleanup(raw_dat_dir+'metsim_0312021.csv', Norm_DTXSID_dict)

# %%
bioTransformerDF.to_csv(processed_dat_dir+'BioTransformer3.csv')
